# %%
# Collects the latest 100 tweets with #Berlin
# Includes tweet metadata AND author info (username, name, followers, etc.)
# Saves everything into a CSV file (berlin_tweets.csv)

# %%
# sign up here: https://developer.twitter.com/en/portal/dashboard

# %%
# Step 2: Import libraries
import requests
import pandas as pd
import urllib

# %%
# Step 3: Insert your Bearer Token here
BEARER_TOKEN = "AAAAAAAAAAAAAAAAAAAAALC83AEAAAAAQZrzE7SdXYfOZxzIHRgfnHDU1I8%3DxD6WrBe33n68gMTpbCzz2GqOCBoH6WBbUIkN96umFzicWTJuec"

# %%
# ✅ Step 4: Prepare encoded query and parameters
raw_query = "#germany lang:en -is:retweet"
query = urllib.parse.quote(raw_query)

max_results = 10  # Max allowed in one request under Free tier

# %%
#tweets metadata
tweet_fields = "tweet.fields=created_at,author_id,lang,public_metrics,conversation_id"
user_fields = "user.fields=username,name,created_at,public_metrics,verified"
expansions = "expansions=author_id"

url = (
    f"https://api.twitter.com/2/tweets/search/recent"
    f"?query={query}&max_results={max_results}&{tweet_fields}&{user_fields}&{expansions}"
)

headers = {
    "Authorization": f"Bearer {BEARER_TOKEN}",
    "User-Agent": "v2RecentSearchPython"
}

# %%
# ✅ Step 5: Make API request (once!)
response = requests.get(url, headers=headers)

# %%
# ✅ Step 6: Handle potential error
if response.status_code != 200:
    print("Error:", response.status_code, response.text)
else:
    data = response.json()

# %%
  # ✅ Step 7: Build user lookup table (It makes it easy to link tweets to the full user information.)
  #When Twitter API returns tweets (especially from search or conversation threads), user details are included separately under data["includes"]["users"].
  users = {u["id"]: u for u in data.get("includes", {}).get("users", [])}

# %%
    # ✅ Step 8: Extract tweets and enrich with author metadata

    results = []
    for tweet in data.get("data", []):
        user = users.get(tweet["author_id"], {})
        tweet_metrics = tweet.get("public_metrics", {})
        user_metrics = user.get("public_metrics", {})

        results.append({
            "tweet_id": tweet["id"],
            "text": tweet["text"],
            "created_at": tweet["created_at"],
            "language": tweet["lang"],
            "conversation_id": tweet.get("conversation_id"),
            "retweets": tweet_metrics.get("retweet_count"),
            "likes": tweet_metrics.get("like_count"),
            "replies": tweet_metrics.get("reply_count"),
            "quotes": tweet_metrics.get("quote_count"),
            "author_id": tweet["author_id"],
            "username": user.get("username"),
            "name": user.get("name"),
            "user_created_at": user.get("created_at"),
            "verified": user.get("verified"),
            "followers": user_metrics.get("followers_count"),
            "following": user_metrics.get("following_count"),
            "tweet_count": user_metrics.get("tweet_count")
        })

# %%
    # ✅ Step 9: Save to CSV
    df = pd.DataFrame(results)
    df.to_csv("germany_tweets.csv", index=False)
    df.head()
# Out:
#               tweet_id                                               text  \
# 0  1985765313875451927  #AR/USDT ✅\nPROFIT: 569.00%\nALL TAKE PROFIT A...
# 1  1985765298146832417  American money is being 'misspent' on arming I...
# 2  1985765121264677033  Germany is set to further solidify its role as...
# 3  1985765038976856082  PAID CHANNEL SIGNALS \n\n#AR/USDT {Long} ✅\n\n...
# 4  1985764793349808373  Money Vocabulary in Spanish for English Speake...
#
#                  created_at language      conversation_id  retweets  likes  \
# 0  2025-11-04T17:45:19.000Z       en  1985765038976856082         0      0
# 1  2025-11-04T17:45:15.000Z       en  1985765298146832417         0      1
# 2  2025-11-04T17:44:33.000Z       en  1985765121264677033         0      0
# 3  2025-11-04T17:44:13.000Z       en  1985765038976856082         0      0
# 4  2025-11-04T17:43:15.000Z       en  1985764793349808373         0      0
#
#    replies  quotes            author_id         username              name  \
# 0        0       0  1866664125415251968       Maxy_Gross         Max Gross
# 1        0       0  1720733372979302400  MohammedOathman  Mohammed Oathman
# 2        0       0  1942939268596559872    gistaipodcast  the Gist News AI
# 3        3       0  1866664125415251968       Maxy_Gross         Max Gross
# 4        1       0           1709755902           aiseCP          Aise *️⃣
#
#             user_created_at  verified  followers  following  tweet_count
# 0  2024-12-11T01:59:55.000Z     False        800        502         4589
# 1  2023-11-04T09:27:03.000Z     False         27         28         2571
# 2  2025-07-09T13:30:14.000Z     False         17        140         1162
# 3  2024-12-11T01:59:55.000Z     False        800        502         4589
# 4  2013-08-29T11:31:57.000Z     False        283        174        41989

# %%
###############################################################################################################################################################

# %%
# post in twitter using python and APIs

# %%
pip install tweepy
# Out:
# Requirement already satisfied: tweepy in /usr/local/lib/python3.11/dist-packages (4.16.0)
# Requirement already satisfied: oauthlib<4,>=3.2.0 in /usr/local/lib/python3.11/dist-packages (from tweepy) (3.3.1)
# Requirement already satisfied: requests<3,>=2.27.0 in /usr/local/lib/python3.11/dist-packages (from tweepy) (2.32.3)
# Requirement already satisfied: requests-oauthlib<3,>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from tweepy) (2.0.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.27.0->tweepy) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.27.0->tweepy) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.27.0->tweepy) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.27.0->tweepy) (2025.7.14)

# %%
import tweepy

# Replace these with your actual credentials
API_KEY = "sKFtXGlLgk09wNfEfpVdN1pS4"
API_SECRET = "AxYOiGGOZg2xAQng2pj2Ux5r2ZxZY8H83fB4GClBMzLfMMHH21"
ACCESS_TOKEN = "1947549611897282560-qp6m7BbH2T3P6wb1eFp1AK45DOg8m2"
ACCESS_TOKEN_SECRET = "LQMvkhEEUm48EUDgKAUsbwq3dJixrUNdykxwoAVr2EsVM"
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 import tweepy
#       3 # Replace these with your actual credentials
#       4 API_KEY = "sKFtXGlLgk09wNfEfpVdN1pS4"
#
# ModuleNotFoundError: No module named 'tweepy'

# %%
# Authenticate to Twitter
auth = tweepy.OAuth1UserHandler(API_KEY, API_SECRET, ACCESS_TOKEN, ACCESS_TOKEN_SECRET)
api = tweepy.API(auth)

# %%
# Your tweet text
tweet_text = "Hello world from German UDS using Tweepy! #Python #API"

# %%
# Post the tweet
try:
    tweet = api.update_status(status=tweet_text)
    print("✅ Tweet successfully posted!")
    print(f"Tweet URL: https://twitter.com/{tweet.user.screen_name}/status/{tweet.id}")
except Exception as e:
    print("❌ Error posting tweet:", e)
# Out:
# ❌ Error posting tweet: 403 Forbidden
# 453 - You currently have access to a subset of X API V2 endpoints and limited v1.1 endpoints (e.g. media post, oauth) only. If you need access to this endpoint, you may need a different access level. You can learn more here: https://developer.x.com/en/portal/product

# %%
| Plan                 | Can Post Tweets? | Monthly Price  |
| -------------------- | ---------------- | -------------- |
| **Free**             | **No**         | \$0            |
| **Basic**            | Yes            | \$100/month    |
| **Pro / Enterprise** | Yes            | Custom pricing |
| **Academic**         | Read-only      | Free           |
